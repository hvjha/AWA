# %% [markdown]
# <a href="https://colab.research.google.com/github/hvjha/AWA/blob/Statistics/stat_class_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables Qualitative Vs Quantitative

# %%
import pandas as pd
data = {
    "student":["A","B","C"],
    "Age":[16,21,18],
    "Marks":[85,83,90],
    "Study-Hour":[2,1.5,3]
}
df = pd.DataFrame(data)
print(df)

#Here student is not a variable , student acts as a identifier or lable and their property like age, marks and study-hour are variables
# Out:
#   student  Age  Marks  Study-Hour
# 0       A   16     85         2.0
# 1       B   21     83         1.5
# 2       C   18     90         3.0

# %% [markdown]
# #Dependent vs Independent variables

# %%
import matplotlib.pyplot as plt
#independent variable(input)
study_hours = [1,2,3,4,5]
#dependent variables(output)
marks = [50,60,70,85,90]

plt.scatter(study_hours,marks, color='purple')
plt.xlabel("Study Hours (independent)")
plt.ylabel("Marks (output)")
plt.title("Study Hours vs Marks")
plt.grid(True)
plt.show()

# %% [markdown]
# This means marks depend on study hour
