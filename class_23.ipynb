# %% [markdown]
# <a href="https://colab.research.google.com/github/hvjha/AWA/blob/Python/class_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data= [2,4,5,6,7,8,9]

# %%
import numpy as np
print(np.mean(data))
# Out:
# 5.857142857142857

# %%
print(np.median(data))
# Out:
# 6.0

# %%
print(np.var(data))
# Out:
# 4.979591836734694

# %%
print(np.std(data))
# Out:
# 2.2314999074019015

# %%
print(np.sum(data))
# Out:
# 41

# %%
print(np.prod(data))
# Out:
# 120960

# %%
print(np.percentile(data,50))
# Out:
# 6.0

# %%
data = [1,2,3,4,5]

# %%
np.cumsum(data)
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
np.cumprod(data)
# Out:
# array([  1,   2,   6,  24, 120])

# %%
x = [1,2,3,4,5]
y= [2,4,6,8,10]
print(np.corrcoef(x,y))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
x = [1,2,3,4]
y= [4,3,2,1]
print(np.corrcoef(x,y))
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
normal_sample = np.random.normal(loc=0,scale=1,size=5)
print(normal_sample)
# Out:
# [-1.78593046 -1.59202094  0.87843884  2.18527566  1.01650974]

# %%
normal_sample = np.random.uniform(low=0,high=10,size=5)
print(normal_sample)
# Out:
# [0.16230827 4.58372562 0.92467727 3.29764905 6.66472296]
