# %%
import pandas as pd
data = pd.DataFrame({'level':['junior','Mid-level','Senior'],
                     'salary':[7500,14500,18200],
                     'position':['Data Analyst','Data Engineer','Data Scientiest']})

# %%
data.head()
# Out:
#        level  salary         position
# 0     junior    7500     Data Analyst
# 1  Mid-level   14500    Data Engineer
# 2     Senior   18200  Data Scientiest

# %%
data.tail(1)
# Out:
#     level  salary         position
# 2  Senior   18200  Data Scientiest

# %%
file_path = 'database.db'

# %%
import os
if os.path.exists(file_path):
    try:
        os.remove(file_path)
        print(f"File {file_path} deleted successfully !")
    except Exception as e:
        print(f"Error deleting the file {file_path}.Details:{e}")
else:
    print(f"File {file_path} not found .")
# Out:
# Error deleting the file database.db.Details:[WinError 32] The process cannot access the file because it is being used by another process: 'database.db'

# %%
import sqlite3

# %%
con = sqlite3.connect('database.db')
data.to_sql('employee', con, if_exists='replace', index=False)
con.close()

# %%
# %load_ext sql
# %config SqlMagic.style = 'ASCII'   # 🔥 THIS LINE FIXES THE ERROR
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///database.db

# %%
# %config SqlMagic.autopandas = True

# %%
# %%sql
# SELECT * FROM employee;
# Out:
#  * sqlite:///database.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT * FROM employee;\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# ...

# %%
pip install --upgrade ipython-sql prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
---to_datetime() -'YYYY-MM-DD'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 ---to_datetime()
#
# NameError: name 'to_datetime' is not defined

# %%
data = {
    "employee_id": [1, 2, 3, 4, 5, 6],
    "join_date": [
        "2024-01-15",
        "2024-02-20",
        "2024-03-05",
        "2024-04-10",
        "2024-05-18",
        "2024-06-01"
    ],
    "login_time": [
        "09:15:00",
        "10:30:45",
        "08:55:10",
        "09:05:00",
        "11:20:35",
        "07:45:50"
    ],
    "department": [
        "IT",
        "HR",
        "Finance",
        "IT",
        "Sales",
        "HR"
    ]
}

# %%
from datetime import datetime,timedelta

# %%
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  6 non-null      int64
#  1   join_date    6 non-null      object
#  2   login_time   6 non-null      object
#  3   department   6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 324.0+ bytes

# %%
df.head()
# Out:
#    employee_id   join_date login_time department
# 0            1  2024-01-15   09:15:00         IT
# 1            2  2024-02-20   10:30:45         HR
# 2            3  2024-03-05   08:55:10    Finance
# 3            4  2024-04-10   09:05:00         IT
# 4            5  2024-05-18   11:20:35      Sales

# %%
df['join_date']=pd.to_datetime(df['join_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  6 non-null      int64
#  1   join_date    6 non-null      datetime64[ns]
#  2   login_time   6 non-null      object
#  3   department   6 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 324.0+ bytes

# %%
df['datetime_column'] = pd.to_datetime(df['join_date'].dt.date.astype(str) + ' ' + df['login_time'])

# %%
df.head()
# Out:
#    employee_id  join_date login_time department     datetime_column
# 0            1 2024-01-15   09:15:00         IT 2024-01-15 09:15:00
# 1            2 2024-02-20   10:30:45         HR 2024-02-20 10:30:45
# 2            3 2024-03-05   08:55:10    Finance 2024-03-05 08:55:10
# 3            4 2024-04-10   09:05:00         IT 2024-04-10 09:05:00
# 4            5 2024-05-18   11:20:35      Sales 2024-05-18 11:20:35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      6 non-null      int64
#  1   join_date        6 non-null      datetime64[ns]
#  2   login_time       6 non-null      object
#  3   department       6 non-null      object
#  4   datetime_column  6 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df['datetime_column'] = df['datetime_column'].dt.date.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      6 non-null      int64
#  1   join_date        6 non-null      datetime64[ns]
#  2   login_time       6 non-null      object
#  3   department       6 non-null      object
#  4   datetime_column  6 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 372.0+ bytes

# %%
df['datetime_new'] = pd.to_datetime(df['join_date'].dt.date.astype(str) + ' ' + df['login_time'])

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new
# 0 2024-01-15 09:15:00
# 1 2024-02-20 10:30:45
# 2 2024-03-05 08:55:10
# 3 2024-04-10 09:05:00
# 4 2024-05-18 11:20:35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      6 non-null      int64
#  1   join_date        6 non-null      datetime64[ns]
#  2   login_time       6 non-null      object
#  3   department       6 non-null      object
#  4   datetime_column  6 non-null      object
#  5   datetime_new     6 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 420.0+ bytes

# %%
df['datetime_new1'] = pd.to_datetime(df['join_date'].dt.date.astype(str) + ' ' + df['login_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      6 non-null      int64
#  1   join_date        6 non-null      datetime64[ns]
#  2   login_time       6 non-null      object
#  3   department       6 non-null      object
#  4   datetime_column  6 non-null      object
#  5   datetime_new     6 non-null      datetime64[ns]
#  6   datetime_new1    6 non-null      datetime64[ns]
# dtypes: datetime64[ns](3), int64(1), object(3)
# memory usage: 468.0+ bytes

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new       datetime_new1
# 0 2024-01-15 09:15:00 2024-01-15 09:15:00
# 1 2024-02-20 10:30:45 2024-02-20 10:30:45
# 2 2024-03-05 08:55:10 2024-03-05 08:55:10
# 3 2024-04-10 09:05:00 2024-04-10 09:05:00
# 4 2024-05-18 11:20:35 2024-05-18 11:20:35

# %%
df['datetime_new1'] = df['datetime_new1'].dt.year.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      6 non-null      int64
#  1   join_date        6 non-null      datetime64[ns]
#  2   login_time       6 non-null      object
#  3   department       6 non-null      object
#  4   datetime_column  6 non-null      object
#  5   datetime_new     6 non-null      datetime64[ns]
#  6   datetime_new1    6 non-null      object
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 468.0+ bytes

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new datetime_new1
# 0 2024-01-15 09:15:00          2024
# 1 2024-02-20 10:30:45          2024
# 2 2024-03-05 08:55:10          2024
# 3 2024-04-10 09:05:00          2024
# 4 2024-05-18 11:20:35          2024

# %%
df['YEAR']=df['datetime_new'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_id      6 non-null      int64
#  1   join_date        6 non-null      datetime64[ns]
#  2   login_time       6 non-null      object
#  3   department       6 non-null      object
#  4   datetime_column  6 non-null      object
#  5   datetime_new     6 non-null      datetime64[ns]
#  6   datetime_new1    6 non-null      object
#  7   YEAR             6 non-null      int32
# dtypes: datetime64[ns](2), int32(1), int64(1), object(4)
# memory usage: 492.0+ bytes

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new datetime_new1  YEAR
# 0 2024-01-15 09:15:00          2024  2024
# 1 2024-02-20 10:30:45          2024  2024
# 2 2024-03-05 08:55:10          2024  2024
# 3 2024-04-10 09:05:00          2024  2024
# 4 2024-05-18 11:20:35          2024  2024

# %%
df['MONTH']=df['datetime_new'].dt.month

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new datetime_new1  YEAR  MONTH
# 0 2024-01-15 09:15:00          2024  2024      1
# 1 2024-02-20 10:30:45          2024  2024      2
# 2 2024-03-05 08:55:10          2024  2024      3
# 3 2024-04-10 09:05:00          2024  2024      4
# 4 2024-05-18 11:20:35          2024  2024      5

# %%
df['DAY']=df['datetime_new'].dt.day

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new datetime_new1  YEAR  MONTH  DAY
# 0 2024-01-15 09:15:00          2024  2024      1   15
# 1 2024-02-20 10:30:45          2024  2024      2   20
# 2 2024-03-05 08:55:10          2024  2024      3    5
# 3 2024-04-10 09:05:00          2024  2024      4   10
# 4 2024-05-18 11:20:35          2024  2024      5   18

# %%
df['WeekDays']=df['datetime_new'].dt.weekday

# %%
df.head()
# Out:
#    employee_id  join_date login_time department datetime_column  \
# 0            1 2024-01-15   09:15:00         IT      2024-01-15
# 1            2 2024-02-20   10:30:45         HR      2024-02-20
# 2            3 2024-03-05   08:55:10    Finance      2024-03-05
# 3            4 2024-04-10   09:05:00         IT      2024-04-10
# 4            5 2024-05-18   11:20:35      Sales      2024-05-18
#
#          datetime_new datetime_new1  YEAR  MONTH  DAY  WeekDays
# 0 2024-01-15 09:15:00          2024  2024      1   15         0
# 1 2024-02-20 10:30:45          2024  2024      2   20         1
# 2 2024-03-05 08:55:10          2024  2024      3    5         1
# 3 2024-04-10 09:05:00          2024  2024      4   10         2
# 4 2024-05-18 11:20:35          2024  2024      5   18         5

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    employee_id   join_date login_time department
# 0            1  2024-01-15   09:15:00         IT
# 1            2  2024-02-20   10:30:45         HR
# 2            3  2024-03-05   08:55:10    Finance
# 3            4  2024-04-10   09:05:00         IT
# 4            5  2024-05-18   11:20:35      Sales
# 5            6  2024-06-01   07:45:50         HR

# %%
df['join_date'] = pd.to_datetime(df['join_date'])

# %%
df['Next_joining_date']=df['join_date']+pd.Timedelta(days=5)

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06

# %%
df['previous_joining_date']=df['join_date']-pd.Timedelta(days=5)

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date  \
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06
#
#   previous_joining_date
# 0            2024-01-10
# 1            2024-02-15
# 2            2024-02-29
# 3            2024-04-05
# 4            2024-05-13
# 5            2024-05-27

# %%
from pandas.tseries.offsets import DateOffset
df['future_month'] = df['join_date'] + pd.DateOffset(months=5)

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date  \
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06
#
#   previous_joining_date future_month
# 0            2024-01-10   2024-06-15
# 1            2024-02-15   2024-07-20
# 2            2024-02-29   2024-08-05
# 3            2024-04-05   2024-09-10
# 4            2024-05-13   2024-10-18
# 5            2024-05-27   2024-11-01

# %%
df['future_year'] = df['join_date'] + pd.DateOffset(years=1)

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date  \
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06
#
#   previous_joining_date future_month future_year
# 0            2024-01-10   2024-06-15  2025-01-15
# 1            2024-02-15   2024-07-20  2025-02-20
# 2            2024-02-29   2024-08-05  2025-03-05
# 3            2024-04-05   2024-09-10  2025-04-10
# 4            2024-05-13   2024-10-18  2025-05-18
# 5            2024-05-27   2024-11-01  2025-06-01

# %%
df['formatted_date'] = df['join_date'].dt.strftime('%d-%m-%Y')

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date  \
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06
#
#   previous_joining_date future_month future_year formatted_date
# 0            2024-01-10   2024-06-15  2025-01-15     15-01-2024
# 1            2024-02-15   2024-07-20  2025-02-20     20-02-2024
# 2            2024-02-29   2024-08-05  2025-03-05     05-03-2024
# 3            2024-04-05   2024-09-10  2025-04-10     10-04-2024
# 4            2024-05-13   2024-10-18  2025-05-18     18-05-2024
# 5            2024-05-27   2024-11-01  2025-06-01     01-06-2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            6 non-null      int64
#  1   join_date              6 non-null      datetime64[ns]
#  2   login_time             6 non-null      object
#  3   department             6 non-null      object
#  4   Next_joining_date      6 non-null      datetime64[ns]
#  5   previous_joining_date  6 non-null      datetime64[ns]
#  6   future_month           6 non-null      datetime64[ns]
#  7   future_year            6 non-null      datetime64[ns]
#  8   formatted_date         6 non-null      object
# dtypes: datetime64[ns](5), int64(1), object(3)
# memory usage: 564.0+ bytes

# %%
df['join_date_new']=pd.to_datetime(df['formatted_date'],format='%d-%m-%Y')

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date  \
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06
#
#   previous_joining_date future_month future_year formatted_date join_date_new
# 0            2024-01-10   2024-06-15  2025-01-15     15-01-2024    2024-01-15
# 1            2024-02-15   2024-07-20  2025-02-20     20-02-2024    2024-02-20
# 2            2024-02-29   2024-08-05  2025-03-05     05-03-2024    2024-03-05
# 3            2024-04-05   2024-09-10  2025-04-10     10-04-2024    2024-04-10
# 4            2024-05-13   2024-10-18  2025-05-18     18-05-2024    2024-05-18
# ...

# %%
df['is_leap_df']=df['join_date_new'].dt.is_leap_year

# %%
df
# Out:
#    employee_id  join_date login_time department Next_joining_date  \
# 0            1 2024-01-15   09:15:00         IT        2024-01-20
# 1            2 2024-02-20   10:30:45         HR        2024-02-25
# 2            3 2024-03-05   08:55:10    Finance        2024-03-10
# 3            4 2024-04-10   09:05:00         IT        2024-04-15
# 4            5 2024-05-18   11:20:35      Sales        2024-05-23
# 5            6 2024-06-01   07:45:50         HR        2024-06-06
#
#   previous_joining_date future_month future_year formatted_date join_date_new  \
# 0            2024-01-10   2024-06-15  2025-01-15     15-01-2024    2024-01-15
# 1            2024-02-15   2024-07-20  2025-02-20     20-02-2024    2024-02-20
# 2            2024-02-29   2024-08-05  2025-03-05     05-03-2024    2024-03-05
# 3            2024-04-05   2024-09-10  2025-04-10     10-04-2024    2024-04-10
# 4            2024-05-13   2024-10-18  2025-05-18     18-05-2024    2024-05-18
# ...

# %%
# !pip install snowflake-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 8.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.6 MB 7.3 MB/s eta 0:00:02
#    -------- ------------------------------- 3.1/14.6 MB 7.9 MB/s eta 0:00:02
#    ------------ --------------------------- 4.5/14.6 MB 7.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.0/14.6 MB 7.4 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.6 MB 7.5 MB/s eta 0:00:01
#    ------------------------ --------------- 8.9/14.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.2/14.6 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 12.3/14.6 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 7.6 MB/s eta 0:00:01
# ...

# %%
# !pip install snowflake-sqlalchemy

# %%
# !pip install "snowflake-connector-python[pandas]"

# %%
import snowflake.connector
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import getpass
import seaborn as sns 
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm

from sqlalchemy import create_engine
from sqlalchemy.engine import URL
from snowflake.connector.pandas_tools import write_pandas

# %%
# Establish the connection
conn = snowflake.connector.connect(
    account= 'wfdmzkv-nr55574',
    user='HARSH3098',
    password = getpass.getpass('Your Snowflake Password: '),
    ##'A6jha@90',
    warehouse='COMPUTE_WH',
    database='eda',
    schema='eda_schema',
    role='ACCOUNTADMIN'
)

# Test the connection
cursor = conn.cursor()
cursor.execute("SELECT CURRENT_VERSION()")
print(cursor.fetchone())
# Out:
# Your Snowflake Password:  ········
# ('9.39.2',)

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM NHANES_MANUAL_UPLOAD")

# %%
NHANES_DATA_RAW = cur.fetch_pandas_all()

# %%
NHANES_DATA_RAW
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
NHANES_DATA_RAW.shape
# Out:
# (5735, 28)

# %%
# Isolate the column 
data = NHANES_DATA_RAW.loc[:,('SEQN','SMQ020', 'RIAGENDR', 'RIDAGEYR','DMDEDUC2','BMXWT', 'BMXHT', 'BMXBMI')]
data.head()
# Out:
#     SEQN  SMQ020  RIAGENDR  RIDAGEYR  DMDEDUC2  BMXWT  BMXHT  BMXBMI
# 0  83732       1         1        62       5.0   94.8  184.5    27.8
# 1  83733       1         1        53       3.0   90.4  171.4    30.8
# 2  83734       1         1        78       3.0   83.4  170.1    28.8
# 3  83735       2         2        56       5.0  109.8  160.9    42.4
# 4  83736       2         2        42       4.0   55.2  164.9    20.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      5735 non-null   int32
#  1   SMQ020    5735 non-null   int8
#  2   RIAGENDR  5735 non-null   int8
#  3   RIDAGEYR  5735 non-null   int8
#  4   DMDEDUC2  5474 non-null   float64
#  5   BMXWT     5666 non-null   float64
#  6   BMXHT     5673 non-null   float64
#  7   BMXBMI    5662 non-null   float64
# dtypes: float64(4), int32(1), int8(3)
# memory usage: 218.6 KB

# %%
# Change the column names to ease the use
data.columns = ['seqn','smoking','gender', 'age','education','weight','height','bmi']

# %%
data.head()
# Out:
#     seqn  smoking  gender  age  education  weight  height   bmi
# 0  83732        1       1   62        5.0    94.8   184.5  27.8
# 1  83733        1       1   53        3.0    90.4   171.4  30.8
# 2  83734        1       1   78        3.0    83.4   170.1  28.8
# 3  83735        2       2   56        5.0   109.8   160.9  42.4
# 4  83736        2       2   42        4.0    55.2   164.9  20.3

# %%
data.shape
# Out:
# (5735, 8)

# %%
# Check for duplicates
duplicateRowsDF = data[data.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [seqn, smoking, gender, age, education, weight, height, bmi]
# Index: []

# %%
data.drop(columns = 'seqn', inplace = True)

# %%
data.head()
# Out:
#    smoking  gender  age  education  weight  height   bmi
# 0        1       1   62        5.0    94.8   184.5  27.8
# 1        1       1   53        3.0    90.4   171.4  30.8
# 2        1       1   78        3.0    83.4   170.1  28.8
# 3        2       2   56        5.0   109.8   160.9  42.4
# 4        2       2   42        4.0    55.2   164.9  20.3

# %%
# Check for missing data
data.isnull().sum()
# Out:
# smoking        0
# gender         0
# age            0
# education    261
# weight        69
# height        62
# bmi           73
# dtype: int64

# %%
data.shape
# Out:
# (5735, 7)

# %%
# Drop the missing values
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (5406, 7)

# %%
data.head()
# Out:
#    smoking  gender  age  education  weight  height   bmi
# 0        1       1   62        5.0    94.8   184.5  27.8
# 1        1       1   53        3.0    90.4   171.4  30.8
# 2        1       1   78        3.0    83.4   170.1  28.8
# 3        2       2   56        5.0   109.8   160.9  42.4
# 4        2       2   42        4.0    55.2   164.9  20.3

# %%
cur.close()
# Out:
# False

# %%
conn.close()

# %%
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine, text
import getpass

engine = create_engine(
    URL(
        account='wfdmzkv-nr55574',
        user='HARSH3098',
        password=getpass.getpass('Your Snowflake Password: '),
        warehouse='COMPUTE_WH',
        database='eda',
        schema='eda_schema',
        role='ACCOUNTADMIN'
    )
)

try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT current_version()"))
        print(result.scalar())
finally:
    engine.dispose()
# Out:
# Your Snowflake Password:  ········
# 9.39.2

# %%
# Push DataFrame to Snowflake
try:
    data.to_sql('NHANES_CLEANED_DATA', con=engine, index=False, if_exists='append', method='multi')
    print("Data uploaded successfully!")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_22388\2943389064.py:3: UserWarning: The provided table name 'NHANES_CLEANED_DATA' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   data.to_sql('NHANES_CLEANED_DATA', con=engine, index=False, if_exists='append', method='multi')
# Data uploaded successfully!

# %%
# Verify the Upload
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM NHANES_CLEANED_DATA LIMIT 10"))
    for row in result:
        print(row)
# Out:
# (1, 1, 62, 5.0, 94.8, 184.5, 27.8)
# (1, 1, 53, 3.0, 90.4, 171.4, 30.8)
# (1, 1, 78, 3.0, 83.4, 170.1, 28.8)
# (2, 2, 56, 5.0, 109.8, 160.9, 42.4)
# (2, 2, 42, 4.0, 55.2, 164.9, 20.3)
# (2, 2, 72, 2.0, 64.4, 150.0, 28.6)
# (1, 1, 22, 4.0, 76.6, 165.4, 28.0)
# (2, 2, 32, 4.0, 64.5, 151.3, 28.2)
# (2, 1, 56, 3.0, 108.3, 179.4, 33.6)
# (1, 1, 46, 5.0, 86.2, 176.7, 27.6)
