# %% [markdown]
# <a href="https://colab.research.google.com/github/hvjha/AWA/blob/Python/class_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var = 'Harsh'

# %%
var1 = "Priti"

# %%
var2 = "Muskan"

# %%
var3 = '''Vaishali'''

# %%
print(var[2])
# Out:
# r

# %%
name = "Prachi"

# %%
len(name)
# Out:
# 6

# %%
print(name[-3])
# Out:
# c

# %%
sen = "Hello, welcome to my clan"
print(len(sen))
# Out:
# 25

# %%
name = "      Harsh      "
print(len(name))
print(name.strip())
print(len(name.strip()))
print(name.lstrip())
print(len(name.lstrip()))
print(name.rstrip())
print(len(name.rstrip()))
# Out:
# 17
# Harsh
# 5
# Harsh
# 11
#       Harsh
# 11

# %%
name = "Muskan singh"
print(name.split())
print(name.split(" "))
# Out:
# ['Muskan', 'singh']
# ['Muskan', 'singh']

# %%
name = "Harsh,Vardhan,Jha,3098"
print(name.split(","))
# Out:
# ['Harsh', 'Vardhan', 'Jha', '3098']

# %%
name = "prachi  "
print(name.rstrip().split('a'))
# Out:
# ['pr', 'chi']

# %%
word = ['Harsh','Jha']
sentences = " | ".join(word)
print(sentences)
# Out:
# Harsh | Jha

# %%
a = " "
b = "Jha"
c = a.join(b)
print(c)
# Out:
# J h a

# %%
my_str = "Hello,Word"
print(my_str.replace("Hello","Hi !"))
# Out:
# Hi !,Word

# %%
name = "Harsh Jha"
print(name.find("Jha"))
# Out:
# 6

# %%
name = "Muskan Singh"
print(name.startswith('M'))
print(name.endswith('h'))
# Out:
# True
# True

# %%
name.count('A')
# Out:
# 0

# %%
print(name[0:6])
# Out:
# Muskan

# %%
string_a='Today is a big day for bihar'

# %%
string_a[0:22:2]
# Out:
# 'Tdyi  i a o'

# %%
string_a[:4]
# Out:
# 'Toda'

# %%
string_a[7:]
# Out:
# 's a big day for bihar'

# %%
string_a[::2]
# Out:
# 'Tdyi  i a o ia'

# %%
string_a[-3:-1]
# Out:
# 'ha'

# %%
string_a[-6:-2]
# Out:
# ' bih'

# %%
name = "Prachi"
print(name[:-2])
# Out:
# Prac

# %%
name[::-1]
# Out:
# 'ihcarP'
