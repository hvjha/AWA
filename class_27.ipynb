# %%
import pandas as pd
data = pd.DataFrame({'level':['junior','Mid-level','Senior'],
                     'salary':[7500,14500,18200],
                     'position':['Data Analyst','Data Engineer','Data Scientiest']})

# %%
data.head()
# Out:
#        level  salary         position
# 0     junior    7500     Data Analyst
# 1  Mid-level   14500    Data Engineer
# 2     Senior   18200  Data Scientiest

# %%
file_path = 'database.db'

# %%
import os
if os.path.exists(file_path):
    try:
        os.remove(file_path)
        print(f"File {file_path} deleted successfully !")
    except Exception as e:
        print(f"Error deleting the file {file_path}.Details:{e}")
else:
    print(f"File {file_path} not found .")
# Out:
# File database.db deleted successfully !

# %%
import sqlite3

# %%
con = sqlite3.connect('database.db')
data.to_sql('employee', con, if_exists='replace', index=False)
# con.close()
# Out:
# 3

# %%
# %load_ext sql

# %%
# %sql sqlite:///database.db

# %%
# %reload_ext sql
# %config SqlMagic.style = 'DEFAULT' 
# %sql sqlite:///database.db

# %%
from prettytable import PrettyTable, TableStyle

# %%
table = PrettyTable()
table.set_style(TableStyle.DEFAULT)

# %%
# %%sql
# SELECT * FROM employee;
# Out:
#  * sqlite:///database.db
# Done.
# [('junior', 7500, 'Data Analyst'),
#  ('Mid-level', 14500, 'Data Engineer'),
#  ('Senior', 18200, 'Data Scientiest')]

# %%
# %%sql
# SELECT COUNT(*) FROM employee
# Out:
#  * sqlite:///database.db
# Done.
# [(3,)]

# %%
# %%sql
# SELECT ROUND(AVG(salary),2) AS AVG_SALARY FROM employee
# Out:
#  * sqlite:///database.db
# Done.
# [(13400.0,)]

# %%
df = pd.read_csv("E:\ANALYTICSWITHANAD\python\dataset.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1      103             30             38       83  43.3
# 1            1      115             70             30       96  34.6
# 2            3      126             88             41      235  39.3
# 3            8       99             84              0        0  35.4
# 4            7      196             90              0        0  39.8
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.183   33        0
# 1                     0.529   32        1
# 2                     0.704   27        0
# 3                     0.388   50        0
# 4                     0.451   41        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.to_sql('diebetes',con, if_exists='replace', index=False)
# Out:
# 768

# %%
# %%sql
# SELECT * FROM diebetes
# Out:
#  * sqlite:///database.db
# Done.
# [(1, 103, 30, 38, 83, 43.3, 0.183, 33, 0),
#  (1, 115, 70, 30, 96, 34.6, 0.529, 32, 1),
#  (3, 126, 88, 41, 235, 39.3, 0.704, 27, 0),
#  (8, 99, 84, 0, 0, 35.4, 0.388, 50, 0),
#  (7, 196, 90, 0, 0, 39.8, 0.451, 41, 1),
#  (6, 148, 72, 35, 0, 33.6, 0.627, 50, 1),
#  (1, 85, 66, 29, 0, 26.6, 0.351, 31, 0),
#  (8, 183, 64, 0, 0, 23.3, 0.672, 32, 1),
#  (1, 89, 66, 23, 94, 28.1, 0.167, 21, 0),
#  (0, 137, 40, 35, 168, 43.1, 2.288, 33, 1),
#  (5, 116, 74, 0, 0, 25.6, 0.201, 30, 0),
#  (3, 78, 50, 32, 88, 31.0, 0.248, 26, 1),
#  (10, 115, 0, 0, 0, 35.3, 0.134, 29, 0),
#  (2, 197, 70, 45, 543, 30.5, 0.158, 53, 1),
#  (8, 125, 96, 0, 0, 0.0, 0.232, 54, 1),
#  (4, 110, 92, 0, 0, 37.6, 0.191, 30, 0),
#  (10, 168, 74, 0, 0, 38.0, 0.537, 34, 1),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1),
#  (7, 100, 0, 0, 0, 30.0, 0.484, 32, 1),
# ...

# %%
# %%sql
# SELECT COUNT(*) FROM diebetes
# Out:
#  * sqlite:///database.db
# Done.
# [(768,)]

# %% [markdown]
# Return patient with a BMI greater than 52 and age between 25 and 30

# %%
# %%sql
# SELECT * FROM diebetes WHERE BMI > 52 AND AGE BETWEEN 25 AND 30
# Out:
#  * sqlite:///database.db
# Done.
# [(0, 162, 76, 56, 100, 53.2, 0.759, 25, 1),
#  (1, 88, 30, 42, 99, 55.0, 0.496, 26, 1),
#  (0, 129, 110, 46, 130, 67.1, 0.319, 26, 1),
#  (5, 115, 98, 0, 0, 52.9, 0.209, 28, 1),
#  (0, 180, 78, 63, 14, 59.4, 2.42, 25, 1)]

# %%
df.query ('BMI > 52 and 25 <= Age <=30')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 120            0      162             76             56      100  53.2
# 125            1       88             30             42       99  55.0
# 177            0      129            110             46      130  67.1
# 303            5      115             98              0        0  52.9
# 445            0      180             78             63       14  59.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 120                     0.759   25        1
# 125                     0.496   26        1
# 177                     0.319   26        1
# 303                     0.209   28        1
# 445                     2.420   25        1

# %% [markdown]
# Execute SQL query to return AGE,GLUCOSE, and Outcomes for patient with Glucose greater than 195

# %%
# %%sql
# SELECT Age, Glucose,Outcome From diebetes WHERE Glucose > 195
# Out:
#  * sqlite:///database.db
# Done.
# [(41, 196, 1),
#  (53, 197, 1),
#  (57, 196, 1),
#  (31, 197, 0),
#  (29, 196, 1),
#  (39, 197, 1),
#  (28, 198, 1),
#  (62, 197, 1),
#  (22, 199, 1)]

# %%
df.query('Glucose > 195')[['Age','Glucose','Outcome']]
# Out:
#      Age  Glucose  Outcome
# 4     41      196        1
# 13    53      197        1
# 206   57      196        1
# 228   31      197        0
# 359   29      196        1
# 408   39      197        1
# 561   28      198        1
# 579   62      197        1
# 661   22      199        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# %%sql
# CREATE TABLE patients (Pregnancies INT,
#                           Glucose INT,
#                        BloodPressure INT,
#                        SkinThickness INT,
#                         Insulin INT,
#                        BMI DECIMAL(8,2),
#                        DiabetesPedigreeFunction DECIMAL(8,2),
#                         Age INT,
#                        Outcome INT)
# Out:
#  * sqlite:///database.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM patients
# Out:
#  * sqlite:///database.db
# Done.
# []

# %%
# %%sql
# INSERT INTO patients SELECT Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age,Outcome
# FROM diebetes WHERE Age > 50;
# Out:
#  * sqlite:///database.db
# 81 rows affected.
# []

# %%
# %%sql
# SELECT * FROM patients
# Out:
#  * sqlite:///database.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0),
#  (8, 181, 68, 36, 495, 30.1, 0.615, 60, 1),
#  (6, 103, 72, 32, 190, 37.7, 0.324, 55, 0),
#  (8, 196, 76, 29, 280, 37.5, 0.605, 57, 1),
# ...

# %%
# %%sql
# ALTER TABLE patients ADD Profile_column VARCHAR(20)
# Out:
#  * sqlite:///database.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM patients
# Out:
#  * sqlite:///database.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1, None),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1, None),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0, None),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1, None),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1, None),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1, None),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0, None),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0, None),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1, None),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1, None),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1, None),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0, None),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1, None),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1, None),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0, None),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1, None),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0, None),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0, None),
#  (8, 181, 68, 36, 495, 30.1, 0.615, 60, 1, None),
# ...

# %%
# %%sql
# UPDATE Patients SET Profile_column = CASE WHEN BMI <=30 THEN 'Normal' ELSE Profile_column END;
# Out:
#  * sqlite:///database.db
# 81 rows affected.
# []

# %% [markdown]
# %%sql
# ALTER TABLE patients
# DROP COLUMN Profile_column;

# %%
# %%sql
# SELECT * FROM patients
# Out:
#  * sqlite:///database.db
# Done.
# [(2, 197, 70, 45, 543, 30.5, 0.158, 53, 1, None),
#  (8, 125, 96, 0, 0, 0, 0.232, 54, 1, 'Normal'),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0, 'Normal'),
#  (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1, None),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1, 'Normal'),
#  (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1, None),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0, 'Normal'),
#  (5, 109, 75, 26, 0, 36, 0.546, 60, 0, None),
#  (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1, None),
#  (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1, None),
#  (8, 176, 90, 34, 300, 33.7, 0.467, 58, 1, None),
#  (2, 109, 92, 0, 0, 42.7, 0.845, 54, 0, None),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1, 'Normal'),
#  (4, 146, 92, 0, 0, 31.2, 0.539, 61, 1, None),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0, 'Normal'),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1, 'Normal'),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0, 'Normal'),
#  (5, 147, 78, 0, 0, 33.7, 0.218, 65, 0, None),
# ...

# %%
# %%sql
# SELECT * FROM patients
# WHERE Profile_column = 'Normal'
# Out:
#  * sqlite:///database.db
# Done.
# [(8, 125, 96, 0, 0, 0, 0.232, 54, 1, 'Normal'),
#  (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0, 'Normal'),
#  (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1, 'Normal'),
#  (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0, 'Normal'),
#  (4, 134, 72, 0, 0, 23.8, 0.277, 60, 1, 'Normal'),
#  (5, 132, 80, 0, 0, 26.8, 0.186, 69, 0, 'Normal'),
#  (0, 105, 84, 0, 0, 27.9, 0.741, 62, 1, 'Normal'),
#  (3, 128, 78, 0, 0, 21.1, 0.268, 55, 0, 'Normal'),
#  (7, 142, 60, 33, 190, 28.8, 0.687, 61, 0, 'Normal'),
#  (5, 114, 74, 0, 0, 24.9, 0.744, 57, 0, 'Normal'),
#  (2, 108, 80, 0, 0, 27, 0.259, 52, 1, 'Normal'),
#  (7, 136, 74, 26, 135, 26, 0.647, 51, 0, 'Normal'),
#  (0, 161, 50, 0, 0, 21.9, 0.254, 65, 0, 'Normal'),
#  (8, 112, 72, 0, 0, 23.6, 0.84, 58, 0, 'Normal'),
#  (6, 194, 78, 0, 0, 23.5, 0.129, 59, 1, 'Normal'),
#  (5, 158, 70, 0, 0, 29.8, 0.207, 63, 0, 'Normal'),
#  (6, 137, 61, 0, 0, 24.2, 0.151, 55, 0, 'Normal'),
#  (2, 119, 0, 0, 0, 19.6, 0.832, 72, 0, 'Normal'),
# ...

# %%
df_Patients = pd.read_sql("SELECT * FROM Patients",con)

# %%
df_Patients
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             2      197             70             45      543  30.5
# 1             8      125             96              0        0   0.0
# 2            10      139             80              0        0  27.1
# 3             1      189             60             23      846  30.1
# 4             5      166             72             19      175  25.8
# ..          ...      ...            ...            ...      ...   ...
# 76            5       97             76             27        0  35.6
# 77            2      105             75              0        0  23.3
# 78            0      123             72              0        0  36.3
# 79            6      190             92              0        0  35.5
# 80           10      101             76             48      180  32.9
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.158   53        1
# ...

# %%
df_Patients['Profile']=df_Patients['BMI'].apply(lambda x: 'Normal' if x<30 else 'None')

# %%
df_Patients
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             2      197             70             45      543  30.5
# 1             8      125             96              0        0   0.0
# 2            10      139             80              0        0  27.1
# 3             1      189             60             23      846  30.1
# 4             5      166             72             19      175  25.8
# ..          ...      ...            ...            ...      ...   ...
# 76            5       97             76             27        0  35.6
# 77            2      105             75              0        0  23.3
# 78            0      123             72              0        0  36.3
# 79            6      190             92              0        0  35.5
# 80           10      101             76             48      180  32.9
#
#     DiabetesPedigreeFunction  Age  Outcome Profile
# 0                      0.158   53        1    None
# ...
