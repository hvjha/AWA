# %% [markdown]
# <a href="https://colab.research.google.com/github/hvjha/AWA/blob/Python/class_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Function
#
# A function is a block of reusable code that performs a specific task, we defined funcyion in python using def keyword
# ```

# %%
def add(a,b):
  return a + b

def div(a,b):
  return a/b

# %%
add(8,9)
# Out:
# 17

# %%
div(8,4)
# Out:
# 2.0

# %%
def greet(name):
  return f"Hello, {name}"

# %%
def greet1(name):
  print(f"Hello, {name}")

# %%
var1 = greet1("Harsh")
print(var1)
# Out:
# Hello, Harsh
# None

# %%
var = greet("Harsh")
print(var)
# Out:
# Hello, Harsh

# %%
greet("Muskan")
# Out:
# 'Hello, Muskan'

# %%
greet("Priti")
# Out:
# 'Hello, Priti'

# %%
greet("Anand")
# Out:
# 'Hello, Anand'

# %%
def greeting (name,msg="Hello"):
  return f"{msg},{name}"

# %%
greeting("Muskan")
# Out:
# 'Hello,Muskan'

# %%
greeting("Muskan",msg = "Good Morning")
# Out:
# 'Good Morning,Muskan'

# %%
def welcome(name,msg):
  return f"{msg},{name}"

# %%
welcome("Harsh","Good Morning")
# Out:
# 'Good Morning,Harsh'

# %%
def sum_all(*args):
  return sum(args)

# %%
sum_all(2,6,87,99,101,234)
# Out:
# 529

# %%
def dict_1(**kwargs):
  return kwargs

# %%
dict_1(name="Harsh",roll_no=1,class1="B.Tech")
# Out:
# {'name': 'Harsh', 'roll_no': 1, 'class1': 'B.Tech'}

# %%
def add(*name):
  return name
add("Aman","Harsh","Muskan","Priti")
# Out:
# ('Aman', 'Harsh', 'Muskan', 'Priti')

# %%
def get_name_age():
  name = input("Enter your name: ")
  age = int(input("Enter your age: "))
  return name,age
get_name_age()
# Out:
# Enter your name: Harsh
# Enter your age: 23
# ('Harsh', 23)

# %%
def get_name_age():
  return "Harsh",20
name,age = get_name_age()
print(name)
print(age)
# Out:
# Harsh
# 20

# %%
def add():
  x = 6 #Local variable
  return x + 2
add()
# Out:
# 8

# %%
x = 9 #Global variable
def add():
  y = 23 #Local variable
  print(y)
  print(f"from inner function: {x}")
  return x+3
add()
print(x)
# Out:
# 23
# from inner function: 9
# 9

# %%
x = 9
def add ():
  y = 10
  #print(y)
  #print(f"inner function: {x}")
  #return x+2
  print(x+2)
#print(add())
add()
print(x)
# Out:
# 11
# None
# 11
# 9

# %%
def add1():
  global a
  a = 12
  return a
print(add1())
print(a)
# Out:
# 12

# %%
a = 14
def add1():
  global a
  a = 12
  return a
print(add1())
print(a)
# Out:
# 12
# 12

# %%
def outer():
  x = "outer"

  def inner():
    nonlocal x
    x = "inner"
  inner()
  print(x)
outer()
# Out:
# inner
