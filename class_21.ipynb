# %% [markdown]
# <a href="https://colab.research.google.com/github/hvjha/AWA/blob/Python/class_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#opening a file
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c30a2f1-c0a3-416f-bed2-787a7736e3bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c30a2f1-c0a3-416f-bed2-787a7736e3bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("DimAccount.csv")
print(df)
# Out:
#     AccountKey  ParentAccountKey                                 AccountName  \
# 0            1              24.0                   Profit and Loss after tax
# 1            2              24.0                                      Income
# 2            3              24.0                                     Expense
# 3            4               2.0                                Sale Revenue
# 4            5               3.0                          Cost of Goods Sold
# 5            6               3.0  Selling, General & Administrative Expenses
# 6            7               6.0                      Administration Expense
# 7            8               6.0                                     IT Cost
# 8            9               6.0                               Human Capital
# 9           10               6.0             Light, Heat, Communication Cost
# 10          11               6.0                              Property Costs
# ...

# %%
with open("DimAccount.csv", "r") as file:
  print(file.read())
# Out:
# AccountKey,ParentAccountKey,AccountName,AccountDescription,AccountType,ValueType
# 1,24.0,Profit and Loss after tax,Profit and Loss after tax,Income,Income
# 2,24.0,Income,Income,Income,Income
# 3,24.0,Expense,Expense,Expense,Expense
# 4,2.0,Sale Revenue,Sale Revenue,Income,Income
# 5,3.0,Cost of Goods Sold,Cost of Goods Sold,Expense,Expense
# 6,3.0,"Selling, General & Administrative Expenses","Selling, General & Administrative Expenses",Expense,Expense
# 7,6.0,Administration Expense,Administration Expense,Expense,Expense
# 8,6.0,IT Cost,IT Cost,Expense,Expense
# 9,6.0,Human Capital,Human Capital,Expense,Expense
# 10,6.0,"Light, Heat, Communication Cost","Light, Heat, Communication Cost",Expense,Expense
# 11,6.0,Property Costs,Property Costs,Expense,Expense
# 12,6.0,Other Expenses,Other Expenses,Expense,Expense
# 13,6.0,Marketing Cost,Marketing & Advertisement Cost,Expense,Expense
# 14,13.0,Holiday Ad Cost,Holiday Ad Cost,Expense,Expense
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-49e5986a-f24d-4e0c-856c-af119372a88f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49e5986a-f24d-4e0c-856c-af119372a88f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = open("dta.txt.txt",'r')
file.read()
# Out:
# 'Harsh'

# %%
file.close()

# %%
file = open("dta.txt.txt",'w')

# %%
file.write("Hello Harsh, Welcome to My class")
# Out:
# 32

# %%
file.close()

# %%
file=open("dta.txt.txt","r")
file.read()
# Out:
# 'Hello Harsh, Welcome to My class'

# %%
file=open("dta.txt.txt","a")
file.write('\n This is lecture no 21 of python')
# Out:
# 33

# %%
file.close()

# %%
with open("dta.txt.txt","r") as file:
  print(file.read())
# Out:
# Hello Harsh, Welcome to My class
#  This is lecture no 21 of python

# %%
with open("dta.txt.txt","a") as file:
  file.write("\n We are learning File Handling")

# %%
file.close()

# %%
with open("dta.txt.txt","r") as file:
  print(file.read())
# Out:
# Hello Harsh, Welcome to My class
#  This is lecture no 21 of python
#  We are learning File Handling

# %%
file.close()

# %%
with open("dta.txt.txt","r") as file:
  print(file.readline())
# Out:
# Hello Harsh, Welcome to My class

# %%
with open("dta.txt.txt","r") as file:
  print(file.readlines())
# Out:
# ['Hello Harsh, Welcome to My class\n', ' This is lecture no 21 of python\n', ' We are learning File Handling']

# %%
with open("dta.txt.txt","a") as file:
  file.write("\n Prachi thoughts us python")

# %%
file.close()

# %%
with open("dta.txt.txt","r") as file:
  print(file.read())
# Out:
# Hello Harsh, Welcome to My class
#  This is lecture no 21 of python
#  We are learning File Handling
#  Prachi thoughts us python

# %%
with open("dta.txt.txt","w") as file:
  file.write("\n Good day for me")

# %%
file.close()

# %%
with open("dta.txt.txt","r") as file:
  print(file.read())
# Out:
#  Good day for me

# %%
with open("dta.txt.txt","a") as file:
  file.write("\n Hello Harsh, Welcome to My class \n  This is lecture no 21 of python \n We are learning File Handling \n  Prachi thoughts us python")

# %%
file.close()

# %%
with open("dta.txt.txt","r") as file:
  print(file.read())
  print(file.tell())
  print(file.seek(10))
  print(file.read())
# Out:
#  Good day for me
#  Hello Harsh, Welcome to My class
#   This is lecture no 21 of python
#  We are learning File Handling
#   Prachi thoughts us python
# 147
# 10
#  for me
#  Hello Harsh, Welcome to My class
#   This is lecture no 21 of python
#  We are learning File Handling
#   Prachi thoughts us python

# %%
file.close()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc7b8e79-ea16-4110-9430-23ccde8a3297" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc7b8e79-ea16-4110-9430-23ccde8a3297">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("amanimage.jpg","rb") as file:
  content = file.read()
  print(content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe1\x02\xbeExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x03\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x01>\xea\x1c\x00\x07\x00\x00\x01\x0c\x00\x00\x002
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(list(uploaded.keys())[0])
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(190.5), np.float64(229.5), np.float64(-0.5))

# %%
import os

# %%
if os.path.exists("data.txt.txt"):
  print("file exists")
else:
  print("file not exist")
# Out:
# file not exist

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9add08ad-ea16-498e-90be-59451f0104fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9add08ad-ea16-498e-90be-59451f0104fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
if os.path.exists("dta.txt.txt"):
  print("file exists")
else:
  print("file not exist")
# Out:
# file exists

# %%
#File Handling
import re
re.findall("\d+","welcome123")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-2197116075.py:3: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d+","welcome123")
# ['123']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12ea548b-3640-44dc-9650-e619b5f9a2f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12ea548b-3640-44dc-9650-e619b5f9a2f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("dtaDest.txt.txt","r") as file:
  content=file.read()
  print(content)
# Out:
# Welcome Harsh 45678

# %%
import re

with open("dtaDest.txt.txt", "r") as file:
    content = file.read()
    print(content)

numbers = re.findall(r"\d+", content)
print(numbers)
# Out:
# Welcome Harsh 45678
# ['45678']

# %%
file.close()

# %%
import string

# %%
print(string.ascii_letters)
print(string.ascii_lowercase)
print(string.ascii_uppercase)
print(string.digits)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789

# %%
import textwrap
text=textwrap.fill("This is sunday and is holiday",width=8)
print(text)
# Out:
# This is
# sunday
# and is
# holiday

# %%
import zlib
zlib.compress(b"Hello word")
# Out:
# b'x\x9c\xf3H\xcd\xc9\xc9W(\xcf/J\x01\x00\x14f\x03\xd1'

# %%
zlib.decompress(b'x\x9c\xf3H\xcd\xc9\xc9W(\xcf/J\x01\x00\x14f\x03\xd1')
# Out:
# b'Hello word'

# %%
import gzip
with gzip.open("file.txt.gz","wt") as file:
  file.write("Hello word")

# %%
import zipfile
with zipfile.ZipFile("file.zip","w") as zip_file
zip_file.write("archive.zip")
