# %%
import boto3
import botocore
from botocore.config import Config
import getpass
import snowflake.connector
import pandas as pd
import os
from io import StringIO
import csv

# %%
# 'C:\\Users\\harsh\\Downloads'
os.getcwd()
# Out:
# 'C:\\Users\\harsh'

# %%
# Set up AWS credentials manually (only for testing)
aws_access_key_id = '***********' #-- your access id
aws_secret_access_key = '******************' #-- your secret acces key
region_name = 'us-east-1'  # Replace with your region

# %%
# Create a session using the manual credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# %%
# Create an S3 client
s3 = session.client('s3')

# %%
# Now you can use the S3 client to perform operations to list all buckets
response = s3.list_buckets()
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': 'EQHGQN3W77JCAMZ1', 'HostId': 'jZKWKSw+Y1KZKKzjAOf0SIc01PgQatMtsVcf3/nL1JA3fwHUolGg09xIs0+jQOWNX/t44zWfDqM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'jZKWKSw+Y1KZKKzjAOf0SIc01PgQatMtsVcf3/nL1JA3fwHUolGg09xIs0+jQOWNX/t44zWfDqM=', 'x-amz-request-id': 'EQHGQN3W77JCAMZ1', 'date': 'Mon, 05 Jan 2026 18:29:31 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'Buckets': [{'Name': 'harshretails', 'CreationDate': datetime.datetime(2025, 11, 24, 10, 30, 6, tzinfo=tzutc()), 'BucketArn': 'arn:aws:s3:::harshretails'}, {'Name': 'icebergharsh', 'CreationDate': datetime.datetime(2025, 12, 27, 17, 34, 34, tzinfo=tzutc()), 'BucketArn': 'arn:aws:s3:::icebergharsh'}], 'Owner': {'ID': '7989b180c3d439e43254b4b54581e8244521f769dc176acee008f1b19ea1442e'}}

# %%
# creating S3 bucket with a unique name
s3.create_bucket(Bucket='harshs3demobucketpy')
# Out:
# {'ResponseMetadata': {'RequestId': 'ZY5MR7JH5KWR1YEY',
#   'HostId': 'RJ+GkhV8l4A4YoS1C0353u4hwCB/4EkHvClGKA9j03ZnSttsJahuTk6cC5EJXPVkOpcW6u5jrwA=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'RJ+GkhV8l4A4YoS1C0353u4hwCB/4EkHvClGKA9j03ZnSttsJahuTk6cC5EJXPVkOpcW6u5jrwA=',
#    'x-amz-request-id': 'ZY5MR7JH5KWR1YEY',
#    'date': 'Mon, 05 Jan 2026 18:34:31 GMT',
#    'location': '/harshs3demobucketpy',
#    'x-amz-bucket-arn': 'arn:aws:s3:::harshs3demobucketpy',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': '/harshs3demobucketpy',
#  'BucketArn': 'arn:aws:s3:::harshs3demobucketpy'}

# %%
#Accessing Specific Bucket Info
# Specify the name of your S3 bucket
bucket_name = 'harshretails'
# List all objects in the specific S3 bucket
response = s3.list_objects_v2(Bucket=bucket_name)
# Print object keys (file names)
if 'Contents' in response:
    for obj in response['Contents']:
        print(f"Object Key: {obj['Key']}")
else:
    print("No objects found in the bucket.")
# Out:
# Object Key: campaign/
# Object Key: campaign/campaign_table.csv
# Object Key: campaign_desc/
# Object Key: campaign_desc/campaign_desc.csv
# Object Key: coupon/
# Object Key: coupon/coupon.csv
# Object Key: coupon_redemption/
# Object Key: coupon_redemption/coupon_redempt.csv
# Object Key: demographic/
# Object Key: demographic/hh_demographic.csv
# Object Key: product/
# Object Key: product/product.csv
# Object Key: transaction/
# Object Key: transaction/trnx177_353.csv
# Object Key: transaction/trnx1_176.csv
# Object Key: transaction/trnx354_530.csv
# Object Key: transaction/trnx531_711.csv

# %%
# UPLOADING A FILE IN A SPECIFIC BUCKET
# Specify the name of your S3 bucket and the file to upload
bucket_name = 'harshs3demobucketpy'
file_name = r"E:\ANALYTICSWITHANAD\python\NHANES.csv"
s3_object_name = 'Harsh/NHANES.csv'  # This is the key in S3 or specific folder name followed by file name inside a bucket folder

# %%
# Upload the file to the specified bucket
s3.upload_file(file_name, bucket_name, s3_object_name)

print(f"File '{file_name}' uploaded to S3 bucket '{bucket_name}' as '{s3_object_name}'.")
# File 'E:\ANALYTICSWITHANAD\python\NHANES.csv' uploaded to S3 bucket 'harshs3demobucketpy' as 'Harsh/NHANES.csv'.
# Out:
# File 'E:\ANALYTICSWITHANAD\python\NHANES.csv' uploaded to S3 bucket 'harshs3demobucketpy' as 'Harsh/NHANES.csv'.

# %%
# DOWNLOADING A FILE FROM A SPECIFIC BUCKET

# Specify the name of your S3 bucket and the file to download
bucket_name = 'harshs3demobucketpy'
s3_object_name = 'Harsh/NHANES.csv'  # The key in S3
download_path = 'E:\\ANALYTICSWITHANAD\\python\\NHANES.csv'  # Local path to save the downloaded file give complete path including file name so as to resolve access denied error

# %%
#Download the file from the S3 bucket
s3.download_file(bucket_name, s3_object_name, download_path)

print(f"File '{s3_object_name}' downloaded from S3 bucket '{bucket_name}' to '{download_path}'.")
# File 'Harsh/NHANES.csv' downloaded from S3 bucket 'harshs3demobucketpy' to 'E:\\ANALYTICSWITHANAD\\python'.
# Out:
# File 'Harsh/NHANES.csv' downloaded from S3 bucket 'harshs3demobucketpy' to 'E:\ANALYTICSWITHANAD\python\NHANES.csv'.

# %%
# DELETING A FILE FROM A SPECIFIC BUCKET
# Specify the name of your S3 bucket and the object to delete
bucket_name = 'harshs3demobucketpy'
s3_object_name = 'Harsh/NHANES.csv'  # The key of the object to delete

# Delete the object from the S3 bucket
s3.delete_object(Bucket=bucket_name, Key=s3_object_name)

print(f"Object '{s3_object_name}' deleted from S3 bucket '{bucket_name}'.")
# Object 'Harsh/NHANES.csv' deleted from S3 bucket 'harshs3demobucketpy'.
# Out:
# Object 'Harsh/NHANES.csv' deleted from S3 bucket 'harshs3demobucketpy'.

# %%
## CREATING A ZERO_BYTE_FILE IN S3
# to create a zero-byte file (empty file) in S3:

# Define the bucket and file name
bucket_name = 'harshs3demobucketpy'
file_name = 'your-zero-byte-file.txt'

# %%
# Create a zero-byte file
s3.put_object(Bucket=bucket_name, Key=file_name, Body=b'')
print(f"Zero-byte file '{file_name}' created in bucket '{bucket_name}'.")
# Zero-byte file 'your-zero-byte-file.txt' created in bucket 'harshs3demobucketpy'
# Out:
# Zero-byte file 'your-zero-byte-file.txt' created in bucket 'harshs3demobucketpy'.
