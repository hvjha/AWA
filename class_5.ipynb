# %%
num =10
print(num)
# Out:
# 10

# %%
num = input("enter a number")
print(num)
print(type(num))
# Out:
# enter a number 25
# 25
# <class 'str'>

# %%
name = input("enter your name")
print("Hello",name)
# Out:
# enter your name Harsh
# Hello Harsh

# %%
num1 = int(input("enter your first number"))
num2 = int(input("enter your second number"))
print(num1+num2)
# Out:
# enter your first number 23
# enter your second number 34
# 57

# %%
username=input("enter your username (default:guest):") or "guest"
print(f"welcome,{username}!")
# Out:
# enter your username (default:guest): Priti
# welcome,Priti!

# %%
a = input("enter a name:")
# Out:
# enter a name: Harsh

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
a = input("enter a number")
# Out:
# enter a number 12

# %%
a = eval(input("enter a number:"))
# Out:
# enter a number: 12

# %%
age = int(input("enter your age:"))
if age>=18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# enter your age: 34
# you are eligible to vote

# %%
marks = float(input("enter your marks:"))
if marks>=90:
    print("Grade A")
elif marks>=80:
    print("Grade B")
elif marks>=70:
    print("Grade C")
elif marks>=60:
    print("Grade D")
else:
    print("Grade E")
# Out:
# enter your marks: 45
# Grade E

# %%
num = int(input("enter a number:"))
if num > 0:
    if num % 2==0:
        print("positive and Even")
    else:
        print("positive and Odd")
elif num == 0:
    print("number is zero")
else:
    print("negative number")
# Out:
# enter a number: 0
# number is zero

# %%
number = int(input("enter your number:"))
if number % 2==0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# enter your number: 321
# Number is odd

# %%
result = "number is even" if number%2==0 else "number is odd"
print(result)
# Out:
# number is odd

# %%
age = int(input("enter the age:"))
if age < 18 and age >=0:
    if age >13:
        print("you are teenager")
    elif age < 13 and age >1:
        print("you are child")
    elif age >=0 and age <1:
        print("you are new born baby")
elif age >=18 :
    if age <50:
        print("you are an adult")
    else:
        print("you are senior citizen")
else:
    print("please enter correct number, age should not be negative")
# Out:
# enter the age: -12
# please enter correct number, age should not be negative
